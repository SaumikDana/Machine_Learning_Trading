# %%
from datetime import datetime, timedelta
from utils import *  

# Call the function and store the result
ticker = 'DELL'

# Set the time frame
end_date = datetime.now()
start_date = end_date - timedelta(days=8)

# Use the function from utils.py to analyze stock options
options_metrics = analyze_stock_options(ticker)

# Print 
print_options_data(ticker, options_metrics)

# Call the plot_stock_history method
plot_stock_history(ticker, start_date, end_date)
# Out:
# ===========================================
# Options data for DELL:
# Average IV for Calls: 0.4547233769461365
# Average IV for Puts: 0.41990038954503195
# Total Call Volume: 4519.0
# Total Call open interest: 55441
# Total Call engagement: 59960.0
# Total Put Volume: 2919.0
# Total Put open interest: 54649
# Total Put engagement: 57568.0
# Number of ITM Call Options: 170
# Number of ITM Put Options: 67
