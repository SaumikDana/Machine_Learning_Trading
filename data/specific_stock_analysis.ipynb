# %%
from datetime import datetime, timedelta
from analyze_stock import * 

# Today
date = datetime.today()

# Set the time frame
end_date = date + timedelta(days=7)
start_date = date - timedelta(days=14)

# Call the function and store the result
tickers =['aehr', 'cmc', 'dal', 'goss', 'nke', 'sgh']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)
# Out:
# ===========================================
# Options data for aehr:
# Average IV for Calls: 0.9596716586685392
# Average IV for Puts: 0.9516882728051814
# Total Call Volume: 985.0
# Total Call open interest: 30172
# Total Call engagement: 31157.0
# Total Put Volume: 1182.0
# Total Put open interest: 10124
# Total Put engagement: 11306.0
# Number of ITM Call Options: 45
# Number of ITM Put Options: 51
# Data fetched for aehr, entries: 29
# ===========================================
# Options data for cmc:
# Average IV for Calls: 0.43516616271461517
# Average IV for Puts: 0.5120920181376138
# Total Call Volume: 610.0
# Total Call open interest: 30252
# Total Call engagement: 30862.0
# Total Put Volume: 589.0
# Total Put open interest: 6849
# Total Put engagement: 7438.0
# Number of ITM Call Options: 42
# Number of ITM Put Options: 20
# Data fetched for cmc, entries: 23
# ===========================================
# Options data for dal:
# Average IV for Calls: 0.6029750922289261
# Average IV for Puts: 0.4943671324356645
# Total Call Volume: 10472.0
# Total Call open interest: 413723
# Total Call engagement: 424195.0
# Total Put Volume: 14937.0
# Total Put open interest: 386825
# Total Put engagement: 401762.0
# Number of ITM Call Options: 190
# Number of ITM Put Options: 138
# Data fetched for dal, entries: 30
# ===========================================
# Options data for goss:
# Average IV for Calls: 2.07736765809955
# Average IV for Puts: 1.250763103407118
# Total Call Volume: 322.0
# Total Call open interest: 46498
# Total Call engagement: 46820.0
# Total Put Volume: 500.0
# Total Put open interest: 13555
# Total Put engagement: 14055.0
# Number of ITM Call Options: 2
# Number of ITM Put Options: 16
# Data fetched for goss, entries: 22
# ===========================================
# Options data for nke:
# Average IV for Calls: 0.4175414894010686
# Average IV for Puts: nan
# Total Call Volume: 24385.0
# Total Call open interest: 415819
# Total Call engagement: 440204.0
# Total Put Volume: 58773.0
# Total Put open interest: 399987.0
# Total Put engagement: 458760.0
# Number of ITM Call Options: 257
# Number of ITM Put Options: 280
# Data fetched for nke, entries: 30
# ===========================================
# Options data for sgh:
# Average IV for Calls: 0.6909876158229284
# Average IV for Puts: 0.9162290403238932
# Total Call Volume: 566.0
# Total Call open interest: 8846
# Total Call engagement: 9412.0
# Total Put Volume: 240.0
# Total Put open interest: 2571
# Total Put engagement: 2811.0
# Number of ITM Call Options: 17
# Number of ITM Put Options: 21
# Data fetched for sgh, entries: 17
