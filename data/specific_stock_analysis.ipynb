# %%
from datetime import datetime, timedelta
from analyze_stock import * 

# Set the time frame
end_date = datetime.today()
start_date = end_date - timedelta(days=21)

# Call the function and store the result
tickers =['aehr', 'sgh']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # P/e ratio
    plot_pe_ratio(ticker, end_date)

    # IV Skew
    plot_iv_skew_upside_downside(options_metrics, end_date, ticker)
# Out:
# ===========================================
# Options data for aehr:
# Average IV for Calls: 1.087396673190209
# Average IV for Puts: 0.9430945516204834
# Total Call Volume: 4814.0
# Total Call open interest: 6581
# Total Call engagement: 11395.0
# Total Put Volume: 3342.0
# Total Put open interest: 8996
# Total Put engagement: 12338.0
# Number of ITM Call Options: 15
# Number of ITM Put Options: 16
# Data fetched for aehr, entries: 382
# ===========================================
# Options data for sgh:
# Average IV for Calls: 0.7601623582628038
# Average IV for Puts: 0.7574635240342883
# Total Call Volume: 5412.0
# Total Call open interest: 1839
# Total Call engagement: 7251.0
# Total Put Volume: 1248.0
# Total Put open interest: 3092
# Total Put engagement: 4340.0
# Number of ITM Call Options: 8
# Number of ITM Put Options: 7
# Data fetched for sgh, entries: 318
