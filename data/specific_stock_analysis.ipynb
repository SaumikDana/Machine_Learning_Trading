# %%
from datetime import datetime, timedelta
from analyze_stock import * 

# Set the time frame
end_date = datetime.today()
start_date = end_date - timedelta(days=21)

# Call the function and store the result
tickers =['aehr', 'sgh']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # P/e ratio
    plot_pe_ratio(ticker, end_date)

    # IV Skew
    plot_iv_skew_for_calls_puts_separately(options_metrics, end_date, ticker)
# Out:
# ===========================================
# Options data for aehr:
# Average IV for Calls: 1.0595365678553426
# Average IV for Puts: 0.9327262412261961
# Total Call Volume: 2076.0
# Total Call open interest: 6581
# Total Call engagement: 8657.0
# Total Put Volume: 754.0
# Total Put open interest: 8996
# Total Put engagement: 9750.0
# Number of ITM Call Options: 15
# Number of ITM Put Options: 16
# Data fetched for aehr, entries: 166
# ===========================================
# Options data for sgh:
# Average IV for Calls: 0.680653692626953
# Average IV for Puts: 0.6948824191623264
# Total Call Volume: 272.0
# Total Call open interest: 1839
# Total Call engagement: 2111.0
# Total Put Volume: 321.0
# Total Put open interest: 3092
# Total Put engagement: 3413.0
# Number of ITM Call Options: 8
# Number of ITM Put Options: 7
# Data fetched for sgh, entries: 132
