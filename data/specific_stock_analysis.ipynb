# %%
from datetime import datetime, timedelta
from analyze_stock import * 
from analyze_options import *

# Today
date = datetime.today()

# Set the time frame
end_date = date + timedelta(days=7)
start_date = date - timedelta(days=14)

# Call the function and store the result
tickers =['aehr', 'cmc', 'goss', 'nke', 'sgh']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # Black Scholes
    analyze_and_plot_greeks(ticker)

    # P/e ratio
    plot_pe_ratio(ticker, date)
# Out:
# ===========================================
# Options data for aehr:
# Average IV for Calls: 1.1253258063973717
# Average IV for Puts: 0.8094656810037035
# Total Call Volume: 2834.0
# Total Call open interest: 31352
# Total Call engagement: 34186.0
# Total Put Volume: 1739.0
# Total Put open interest: 10823
# Total Put engagement: 12562.0
# Number of ITM Call Options: 37
# Number of ITM Put Options: 60
# Data fetched for aehr, entries: 386
# ===========================================
# Options data for cmc:
# Average IV for Calls: 0.4880821094576831
# Average IV for Puts: 0.5041078891993205
# Total Call Volume: 561.0
# Total Call open interest: 30433
# Total Call engagement: 30994.0
# Total Put Volume: 601.0
# Total Put open interest: 6903
# Total Put engagement: 7504.0
# Number of ITM Call Options: 36
# Number of ITM Put Options: 27
# Data fetched for cmc, entries: 351
# ===========================================
# Options data for goss:
# Average IV for Calls: 2.158959631520281
# Average IV for Puts: 1.5083209706488716
# Total Call Volume: 631.0
# Total Call open interest: 46594
# Total Call engagement: 47225.0
# Total Put Volume: 510.0
# Total Put open interest: 13557
# Total Put engagement: 14067.0
# Number of ITM Call Options: 2
# Number of ITM Put Options: 16
# Data fetched for goss, entries: 262
# ===========================================
# Options data for nke:
# Average IV for Calls: 0.407560633870268
# Average IV for Puts: nan
# Total Call Volume: 51559.0
# Total Call open interest: 379338
# Total Call engagement: 430897.0
# Total Put Volume: 135880.0
# Total Put open interest: 381719.0
# Total Put engagement: 517599.0
# Number of ITM Call Options: 219
# Number of ITM Put Options: 293
# Data fetched for nke, entries: 387
# ===========================================
# Options data for sgh:
# Average IV for Calls: 0.880000508977981
# Average IV for Puts: 0.9111713497416177
# Total Call Volume: 796.0
# Total Call open interest: 8892
# Total Call engagement: 9688.0
# Total Put Volume: 2472.0
# Total Put open interest: 4602
# Total Put engagement: 7074.0
# Number of ITM Call Options: 17
# Number of ITM Put Options: 21
# Data fetched for sgh, entries: 322
