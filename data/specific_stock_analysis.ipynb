# %%
from datetime import datetime, timedelta
from utils import *  

# Call the function and store the result
ticker = 'NKE'

# Call the function and store the result
day = '2023-12-22'

# Set the time frame
date = datetime.strptime(day, '%Y-%m-%d')
end_date = date + timedelta(days=7)
start_date = date - timedelta(days=7)

# Use the function from utils.py to analyze stock options
options_metrics = analyze_stock_options(ticker)

# Print 
print_options_data(ticker, options_metrics)

# Call the plot_stock_history method
plot_stock_history(ticker, start_date, end_date)
# Out:
# ===========================================
# Options data for NKE:
# Average IV for Calls: 0.09803952050945201
# Average IV for Puts: nan
# Total Call Volume: 185908.0
# Total Call open interest: 369226
# Total Call engagement: 555134.0
# Total Put Volume: 141169.0
# Total Put open interest: 377793.0
# Total Put engagement: 518962.0
# Number of ITM Call Options: 251
# Number of ITM Put Options: 286
