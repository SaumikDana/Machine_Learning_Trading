# %%
from datetime import datetime, timedelta
from utils import *  

# Call the function and store the result
ticker = 'KMX'

# Call the function and store the result
day = '2023-12-22'

# Set the time frame
date = datetime.strptime(day, '%Y-%m-%d')
end_date = date + timedelta(days=7)
start_date = date - timedelta(days=7)

# Use the function from utils.py to analyze stock options
options_metrics = analyze_stock_options(ticker)

# Print 
print_options_data(ticker, options_metrics)

# Call the plot_stock_history method
plot_stock_history(ticker, start_date, end_date)
# Out:
# ===========================================
# Options data for KMX:
# Average IV for Calls: 0.4884066500375342
# Average IV for Puts: 0.5474772859456866
# Total Call Volume: 5788.0
# Total Call open interest: 51360.0
# Total Call engagement: 57148.0
# Total Put Volume: 8724.0
# Total Put open interest: 73149.0
# Total Put engagement: 81873.0
# Number of ITM Call Options: 154
# Number of ITM Put Options: 114
