# %%
from datetime import datetime, timedelta
from analyze_stock import * 

# Set the time frame
end_date = datetime.today()
start_date = end_date - timedelta(days=21)

# Call the function and store the result
tickers =['apld']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # P/e ratio
    plot_pe_ratio(ticker, end_date)

    # IV Skew
    plot_iv_skew_otm_only(options_metrics, end_date, ticker)
# Out:
# ===========================================
# Options data for apld:
# Average IV for Calls: 1.4627033069882147
# Average IV for Puts: 1.252414851592093
# Total Call Volume: 3040.0
# Total Call open interest: 79510
# Total Call engagement: 82550.0
# Total Put Volume: 1530.0
# Total Put open interest: 14482
# Total Put engagement: 16012.0
# Number of ITM Call Options: 34
# Number of ITM Put Options: 8
# Data fetched for apld, entries: 234
