# %%
from datetime import datetime, timedelta
from utils import *  

# Call the function and store the result
ticker = 'NKE'

# Call the function and store the result
day = '2023-12-21'

# Set the time frame
release_date = datetime.strptime(day, '%Y-%m-%d')
end_date = release_date + timedelta(days=7)
start_date = release_date - timedelta(days=7)

# Use the function from utils.py to analyze stock options
options_metrics = analyze_stock_options(ticker)

# Print 
print_options_data(ticker, options_metrics)

# Call the plot_stock_history method
plot_stock_history(ticker, start_date, end_date)
# Out:
# ===========================================
# Options data for NKE:
# Average IV for Calls: 0.0432036109467139
# Average IV for Puts: nan
# Total Call Volume: 121661.0
# Total Call open interest: 5282
# Total Call engagement: 126943.0
# Total Put Volume: 118327.0
# Total Put open interest: 475.0
# Total Put engagement: 118802.0
# Number of ITM Call Options: 350
# Number of ITM Put Options: 126
