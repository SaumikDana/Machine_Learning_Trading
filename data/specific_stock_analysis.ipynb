# %%
from datetime import datetime, timedelta
from analyze_stock import * 

# Set the time frame
end_date = datetime.today()
start_date = end_date - timedelta(days=21)

# Call the function and store the result
tickers =['apld', 'aehr']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # P/e ratio
    plot_pe_ratio(ticker, end_date)

    # IV Skew
    plot_iv_skew_otm_only(options_metrics, end_date, ticker)
# Out:
# ===========================================
# Options data for apld:
# Average IV for Calls: 1.5112921599609372
# Average IV for Puts: 1.2515073973289697
# Total Call Volume: 1732.0
# Total Call open interest: 44143
# Total Call engagement: 45875.0
# Total Put Volume: 474.0
# Total Put open interest: 31322
# Total Put engagement: 31796.0
# Number of ITM Call Options: 28
# Number of ITM Put Options: 10
# Number of OTM Call Options: 22
# Number of OTM Put Options: 27
# Data fetched for apld, entries: 303
# ===========================================
# Options data for aehr:
# Average IV for Calls: 0.8015413554944489
# Average IV for Puts: 0.7062915927124025
# Total Call Volume: 1160.0
# Total Call open interest: 4435
# Total Call engagement: 5595.0
# Total Put Volume: 1489.0
# Total Put open interest: 8174
# Total Put engagement: 9663.0
# Number of ITM Call Options: 4
# Number of ITM Put Options: 16
# Number of OTM Call Options: 15
# Number of OTM Put Options: 8
# Data fetched for aehr, entries: 303
