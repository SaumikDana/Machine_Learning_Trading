# %%
from datetime import datetime, timedelta
from analyze_stock import * 

# Set the time frame
end_date = datetime.today()
start_date = end_date - timedelta(days=21)

# Call the function and store the result
tickers =['aehr', 'cmc', 'sgh']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # P/e ratio
    plot_pe_ratio(ticker, end_date)
# Out:
# ===========================================
# Options data for aehr:
# Average IV for Calls: 1.0455291236597175
# Average IV for Puts: 0.7857030163574219
# Total Call Volume: 1497
# Total Call open interest: 26248
# Total Call engagement: 27745
# Total Put Volume: 1509.0
# Total Put open interest: 8244
# Total Put engagement: 9753.0
# Number of ITM Call Options: 8
# Number of ITM Put Options: 33
# Data fetched for aehr, entries: 324
# ===========================================
# Options data for cmc:
# Average IV for Calls: 0.5077332358805339
# Average IV for Puts: 0.5751762611258371
# Total Call Volume: 954.0
# Total Call open interest: 20277
# Total Call engagement: 21231.0
# Total Put Volume: 581.0
# Total Put open interest: 4580
# Total Put engagement: 5161.0
# Number of ITM Call Options: 12
# Number of ITM Put Options: 9
# Data fetched for cmc, entries: 355
# ===========================================
# Options data for sgh:
# Average IV for Calls: 1.0704785906427559
# Average IV for Puts: 1.0255769163513182
# Total Call Volume: 386.0
# Total Call open interest: 8443
# Total Call engagement: 8829.0
# Total Put Volume: 273.0
# Total Put open interest: 3987
# Total Put engagement: 4260.0
# Number of ITM Call Options: 9
# Number of ITM Put Options: 6
# Data fetched for sgh, entries: 237
