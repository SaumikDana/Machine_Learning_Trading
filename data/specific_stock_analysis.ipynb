# %%
from datetime import datetime, timedelta
from analyze_stock import * 

# Set the time frame
end_date = datetime.today()
start_date = end_date - timedelta(days=21)

# Call the function and store the result
tickers =['aehr', 'cmc', 'sgh']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # P/e ratio
    plot_pe_ratio(ticker, end_date)

    # IV Skew
    plot_iv_skew_for_calls_puts_separately(options_metrics, end_date, ticker)
# Out:
# ===========================================
# Options data for aehr:
# Average IV for Calls: 1.0221042450541835
# Average IV for Puts: 0.8834591791915892
# Total Call Volume: 861.0
# Total Call open interest: 4688
# Total Call engagement: 5549.0
# Total Put Volume: 1059.0
# Total Put open interest: 7384
# Total Put engagement: 8443.0
# Number of ITM Call Options: 15
# Number of ITM Put Options: 16
# Data fetched for aehr, entries: 355
# ===========================================
# Options data for cmc:
# Average IV for Calls: 0.47515947580973306
# Average IV for Puts: 0.47865641998940317
# Total Call Volume: 1039.0
# Total Call open interest: 28446
# Total Call engagement: 29485.0
# Total Put Volume: 631.0
# Total Put open interest: 6199
# Total Put engagement: 6830.0
# Number of ITM Call Options: 26
# Number of ITM Put Options: 19
# Data fetched for cmc, entries: 386
# ===========================================
# Options data for sgh:
# Average IV for Calls: 0.6767802266751803
# Average IV for Puts: 0.6190956059570312
# Total Call Volume: 44.0
# Total Call open interest: 860
# Total Call engagement: 904.0
# Total Put Volume: 130.0
# Total Put open interest: 2914
# Total Put engagement: 3044.0
# Number of ITM Call Options: 8
# Number of ITM Put Options: 4
# Data fetched for sgh, entries: 267
