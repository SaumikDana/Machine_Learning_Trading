# %%
from datetime import datetime, timedelta
from utils import *  

# Call the function and store the result
ticker = 'MU'

# Set the time frame
end_date = datetime.now()
start_date = end_date - timedelta(days=8)

# Use the function from utils.py to analyze stock options
options_metrics = analyze_stock_options(ticker)

# Print 
print_options_data(ticker, options_metrics)

# Call the plot_stock_history method
plot_stock_history(ticker, start_date, end_date)
# Out:
# ===========================================
# Options data for MU:
# Average IV for Calls: 0.5284264322464353
# Average IV for Puts: 0.5061948913744374
# Total Call Volume: 271932.0
# Total Call open interest: 538252
# Total Call engagement: 810184.0
# Total Put Volume: 165445.0
# Total Put open interest: 645969.0
# Total Put engagement: 811414.0
# Number of ITM Call Options: 355
# Number of ITM Put Options: 66
