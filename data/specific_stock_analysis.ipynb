# %%
from datetime import datetime, timedelta
from analyze_stock import * 
from analyze_options import *

# Set the time frame
end_date = datetime.today()
start_date = end_date - timedelta(days=21)

# Call the function and store the result
tickers =['aehr', 'cmc', 'goss', 'nke', 'sgh']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # P/e ratio
    plot_pe_ratio(ticker, end_date)
# Out:
# ===========================================
# Options data for aehr:
# Average IV for Calls: 1.1231169388049058
# Average IV for Puts: 0.828579095417502
# Total Call Volume: 1098.0
# Total Call open interest: 33782
# Total Call engagement: 34880.0
# Total Put Volume: 1086.0
# Total Put open interest: 11930
# Total Put engagement: 13016.0
# Number of ITM Call Options: 37
# Number of ITM Put Options: 60
# Data fetched for aehr, entries: 50
# ===========================================
# Options data for cmc:
# Average IV for Calls: 0.5211791354078271
# Average IV for Puts: 0.4978673626932779
# Total Call Volume: 495.0
# Total Call open interest: 30555
# Total Call engagement: 31050.0
# Total Put Volume: 412.0
# Total Put open interest: 7276
# Total Put engagement: 7688.0
# Number of ITM Call Options: 36
# Number of ITM Put Options: 27
# Data fetched for cmc, entries: 49
# ===========================================
# Options data for goss:
# Average IV for Calls: 2.1300133383394493
# Average IV for Puts: 1.4013054276258678
# Total Call Volume: 597.0
# Total Call open interest: 46876
# Total Call engagement: 47473.0
# Total Put Volume: 511.0
# Total Put open interest: 13557
# Total Put engagement: 14068.0
# Number of ITM Call Options: 2
# Number of ITM Put Options: 16
# Data fetched for goss, entries: 30
# ===========================================
# Options data for nke:
# Average IV for Calls: 0.4568578457838025
# Average IV for Puts: nan
# Total Call Volume: 19884.0
# Total Call open interest: 410287
# Total Call engagement: 430171.0
# Total Put Volume: 27032.0
# Total Put open interest: 394433.0
# Total Put engagement: 421465.0
# Number of ITM Call Options: 214
# Number of ITM Put Options: 299
# Data fetched for nke, entries: 51
# ===========================================
# Options data for sgh:
# Average IV for Calls: 0.8646422385319301
# Average IV for Puts: 0.9146623171691894
# Total Call Volume: 735.0
# Total Call open interest: 9012
# Total Call engagement: 9747.0
# Total Put Volume: 246.0
# Total Put open interest: 4574
# Total Put engagement: 4820.0
# Number of ITM Call Options: 17
# Number of ITM Put Options: 21
# Data fetched for sgh, entries: 31
