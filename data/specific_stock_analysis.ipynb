# %%
from datetime import datetime, timedelta
from analyze_stock import * 

# Set the time frame
end_date = datetime.today()
start_date = end_date - timedelta(days=21)

# Call the function and store the result
tickers =['apld', 'aehr', 'goss']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # P/e ratio
    plot_pe_ratio(ticker, end_date)

    # IV Skew
    plot_iv_skew_otm_only(options_metrics, end_date, ticker)

    # Sector ETF Time Series
    plot_historical_data(get_sector_etf_for_stock(ticker), start_date, end_date)
# Out:
# ===========================================
# Options data for apld:
# Average IV for Calls: 1.118731282489483
# Average IV for Puts: 1.1898533511352538
# Total Call Volume: 3217.0
# Total Call open interest: 10733
# Total Call engagement: 13950.0
# Total Put Volume: 1142.0
# Total Put open interest: 38831
# Total Put engagement: 39973.0
# Number of ITM Call Options: 7
# Number of ITM Put Options: 24
# Number of OTM Call Options: 19
# Number of OTM Put Options: 8
# ===========================================
# ===========================================
# Options data for aehr:
# Average IV for Calls: 0.9040034648640951
# Average IV for Puts: 0.6999340456136068
# Total Call Volume: 524.0
# Total Call open interest: 5543
# Total Call engagement: 6067.0
# Total Put Volume: 402.0
# Total Put open interest: 8140
# Total Put engagement: 8542.0
# Number of ITM Call Options: 8
# Number of ITM Put Options: 16
# Number of OTM Call Options: 16
# Number of OTM Put Options: 8
# ===========================================
# ===========================================
# Options data for goss:
# Average IV for Calls: 1.5149774772135416
# Average IV for Puts: 1.6848996809895833
# Total Call Volume: 88.0
# Total Call open interest: 32738
# Total Call engagement: 32826.0
# Total Put Volume: 223.0
# Total Put open interest: 10744
# Total Put engagement: 10967.0
# Number of ITM Call Options: 0
# Number of ITM Put Options: 6
# Number of OTM Call Options: 6
# Number of OTM Put Options: 0
# ===========================================
# Insufficient variation in strike prices or expiration dates for interpolation.
