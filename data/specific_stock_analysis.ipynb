# %%
from datetime import datetime, timedelta
from analyze_stock import * 
from analyze_options import *

# Today
date = datetime.today()

# Set the time frame
end_date = date + timedelta(days=7)
start_date = date - timedelta(days=14)

# Call the function and store the result
tickers =['aehr', 'cmc', 'goss', 'nke', 'sgh']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # Black Scholes
    analyze_and_plot_greeks(ticker)

    # P/e ratio
    plot_pe_ratio(ticker, date)
# Out:
# ===========================================
# Options data for aehr:
# Average IV for Calls: 1.089084866273639
# Average IV for Puts: 0.8377258155587095
# Total Call Volume: 1134.0
# Total Call open interest: 32790
# Total Call engagement: 33924.0
# Total Put Volume: 1200.0
# Total Put open interest: 11213
# Total Put engagement: 12413.0
# Number of ITM Call Options: 37
# Number of ITM Put Options: 60
# Data fetched for aehr, entries: 64
# ===========================================
# Options data for cmc:
# Average IV for Calls: 0.4876594748494066
# Average IV for Puts: 0.5108441819742838
# Total Call Volume: 574.0
# Total Call open interest: 30538
# Total Call engagement: 31112.0
# Total Put Volume: 605.0
# Total Put open interest: 7043
# Total Put engagement: 7648.0
# Number of ITM Call Options: 36
# Number of ITM Put Options: 27
# Data fetched for cmc, entries: 59
# ===========================================
# Options data for goss:
# Average IV for Calls: 1.9324715849658698
# Average IV for Puts: 1.606731045247396
# Total Call Volume: 601.0
# Total Call open interest: 46854
# Total Call engagement: 47455.0
# Total Put Volume: 510.0
# Total Put open interest: 13557
# Total Put engagement: 14067.0
# Number of ITM Call Options: 2
# Number of ITM Put Options: 16
# Data fetched for goss, entries: 26
# /Users/saumikdana/Machine_Learning_Trading/data/analyze_options.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   d1 = (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
# /Users/saumikdana/Machine_Learning_Trading/data/analyze_options.py:72: RuntimeWarning: invalid value encountered in scalar divide
#   gamma = si.norm.pdf(d1, 0.0, 1.0) / (S * sigma * np.sqrt(T))
# ===========================================
# Options data for nke:
# Average IV for Calls: 0.39293328081756557
# Average IV for Puts: nan
# Total Call Volume: 20042.0
# Total Call open interest: 397961
# Total Call engagement: 418003.0
# Total Put Volume: 101382.0
# Total Put open interest: 386303.0
# Total Put engagement: 487685.0
# Number of ITM Call Options: 214
# Number of ITM Put Options: 299
# Data fetched for nke, entries: 65
# /Users/saumikdana/Machine_Learning_Trading/data/analyze_options.py:67: RuntimeWarning: divide by zero encountered in scalar divide
#   d1 = (np.log(S / K) + (r + 0.5 * sigma ** 2) * T) / (sigma * np.sqrt(T))
# /Users/saumikdana/Machine_Learning_Trading/data/analyze_options.py:72: RuntimeWarning: invalid value encountered in scalar divide
#   gamma = si.norm.pdf(d1, 0.0, 1.0) / (S * sigma * np.sqrt(T))
# /Users/saumikdana/Machine_Learning_Trading/data/analyze_options.py:73: RuntimeWarning: invalid value encountered in scalar divide
#   theta = -((S * si.norm.pdf(d1, 0.0, 1.0) * sigma) / (2 * np.sqrt(T))) + r * K * np.exp(-r * T) * si.norm.cdf(-d2, 0.0, 1.0)
# ===========================================
# Options data for sgh:
# Average IV for Calls: 0.8570122843206498
# Average IV for Puts: 0.8829828032226562
# Total Call Volume: 796.0
# Total Call open interest: 8984
# Total Call engagement: 9780.0
# Total Put Volume: 227.0
# Total Put open interest: 4582
# Total Put engagement: 4809.0
# Number of ITM Call Options: 17
# Number of ITM Put Options: 21
# Data fetched for sgh, entries: 44
