# %%
from datetime import datetime, timedelta
from analyze_stock import * 

# Set the time frame
end_date = datetime.today()
start_date = end_date - timedelta(days=21)

# Call the function and store the result
tickers =['aehr', 'cmc', 'sgh']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # P/e ratio
    plot_pe_ratio(ticker, end_date)
# Out:
# ===========================================
# Options data for aehr:
# Average IV for Calls: 1.0639932452392582
# Average IV for Puts: 0.7930614312744139
# Total Call Volume: 1393
# Total Call open interest: 25425
# Total Call engagement: 26818
# Total Put Volume: 1488.0
# Total Put open interest: 8667
# Total Put engagement: 10155.0
# Number of ITM Call Options: 13
# Number of ITM Put Options: 29
# Data fetched for aehr, entries: 240
# ===========================================
# Options data for cmc:
# Average IV for Calls: 0.5058417373755669
# Average IV for Puts: 0.5808553770177507
# Total Call Volume: 778.0
# Total Call open interest: 20308
# Total Call engagement: 21086.0
# Total Put Volume: 482.0
# Total Put open interest: 4430
# Total Put engagement: 4912.0
# Number of ITM Call Options: 12
# Number of ITM Put Options: 8
# Data fetched for cmc, entries: 261
# ===========================================
# Options data for sgh:
# Average IV for Calls: 1.3640734620079633
# Average IV for Puts: 1.204971330383301
# Total Call Volume: 389.0
# Total Call open interest: 8652
# Total Call engagement: 9041.0
# Total Put Volume: 220.0
# Total Put open interest: 4085
# Total Put engagement: 4305.0
# Number of ITM Call Options: 11
# Number of ITM Put Options: 8
# Data fetched for sgh, entries: 161
