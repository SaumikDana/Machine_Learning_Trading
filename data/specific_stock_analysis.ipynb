# %%
from datetime import datetime, timedelta
from analyze_stock import * 

# Set the time frame
end_date = datetime.today()
start_date = end_date - timedelta(days=21)

# Call the function and store the result
tickers =['apld', 'nke']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # P/e ratio
    plot_pe_ratio(ticker, end_date)

    # IV Skew
    plot_iv_skew_otm_only(options_metrics, end_date, ticker)
# Out:
# ===========================================
# Options data for apld:
# Average IV for Calls: 1.3986847816894528
# Average IV for Puts: 1.1998955093301307
# Total Call Volume: 6248.0
# Total Call open interest: 44729
# Total Call engagement: 50977.0
# Total Put Volume: 445.0
# Total Put open interest: 31247
# Total Put engagement: 31692.0
# Number of ITM Call Options: 22
# Number of ITM Put Options: 14
# Number of OTM Call Options: 28
# Number of OTM Put Options: 23
# Data fetched for apld, entries: 121
# ===========================================
# Options data for nke:
# Average IV for Calls: 0.37408282946795124
# Average IV for Puts: 0.3224733030304127
# Total Call Volume: 21925.0
# Total Call open interest: 270061
# Total Call engagement: 291986.0
# Total Put Volume: 59748.0
# Total Put open interest: 351458.0
# Total Put engagement: 411206.0
# Number of ITM Call Options: 151
# Number of ITM Put Options: 173
# Number of OTM Call Options: 192
# Number of OTM Put Options: 181
# Data fetched for nke, entries: 121
