# %%
from datetime import datetime, timedelta
from analyze_stock import * 

# Call the function and store the result
day = '2023-12-29'

# Set the time frame
date = datetime.strptime(day, '%Y-%m-%d')
end_date = date + timedelta(days=7)
start_date = date - timedelta(days=14)

# Call the function and store the result
tickers =['aehr', 'cmc', 'dal', 'goss', 'nke', 'sgh']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)
# Out:
# ===========================================
# Options data for aehr:
# Average IV for Calls: 0.18159770711474016
# Average IV for Puts: 0.4218903449913424
# Total Call Volume: 1390.0
# Total Call open interest: 30172
# Total Call engagement: 31562.0
# Total Put Volume: 1398.0
# Total Put open interest: 10124
# Total Put engagement: 11522.0
# Number of ITM Call Options: 45
# Number of ITM Put Options: 51
# Data fetched for aehr, entries: 355
# ===========================================
# Options data for cmc:
# Average IV for Calls: 0.1405517086819052
# Average IV for Puts: 0.3223681768697103
# Total Call Volume: 618.0
# Total Call open interest: 30252
# Total Call engagement: 30870.0
# Total Put Volume: 589.0
# Total Put open interest: 6849
# Total Put engagement: 7438.0
# Number of ITM Call Options: 42
# Number of ITM Put Options: 20
# Data fetched for cmc, entries: 311
# ===========================================
# Options data for dal:
# Average IV for Calls: 0.06759972976678215
# Average IV for Puts: 0.1728689779524591
# Total Call Volume: 13923.0
# Total Call open interest: 413723
# Total Call engagement: 427646.0
# Total Put Volume: 18685.0
# Total Put open interest: 386825
# Total Put engagement: 405510.0
# Number of ITM Call Options: 193
# Number of ITM Put Options: 135
# Data fetched for dal, entries: 390
# ===========================================
# Options data for goss:
# Average IV for Calls: 1.0102256442599826
# Average IV for Puts: 0.4927812578125001
# Total Call Volume: 414.0
# Total Call open interest: 46498
# Total Call engagement: 46912.0
# Total Put Volume: 500.0
# Total Put open interest: 13555
# Total Put engagement: 14055.0
# Number of ITM Call Options: 2
# Number of ITM Put Options: 16
# Data fetched for goss, entries: 347
# ===========================================
# Options data for nke:
# Average IV for Calls: 0.09298906998343517
# Average IV for Puts: nan
# Total Call Volume: 95650.0
# Total Call open interest: 415819
# Total Call engagement: 511469.0
# Total Put Volume: 84689.0
# Total Put open interest: 399987.0
# Total Put engagement: 484676.0
# Number of ITM Call Options: 251
# Number of ITM Put Options: 286
# Data fetched for nke, entries: 390
# ===========================================
# Options data for sgh:
# Average IV for Calls: 0.31951417432657875
# Average IV for Puts: 0.5667957992655436
# Total Call Volume: 566.0
# Total Call open interest: 8846
# Total Call engagement: 9412.0
# Total Put Volume: 240.0
# Total Put open interest: 2571
# Total Put engagement: 2811.0
# Number of ITM Call Options: 17
# Number of ITM Put Options: 21
# Data fetched for sgh, entries: 184
