# %%
from datetime import datetime, timedelta
from analyze_stock import * 

# Set the time frame
end_date = datetime.today()
start_date = end_date - timedelta(days=21)

# Call the function and store the result
tickers =['aehr', 'cmc', 'sgh']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # P/e ratio
    plot_pe_ratio(ticker, end_date)
# Out:
# ===========================================
# Options data for aehr:
# Average IV for Calls: 1.0330668861475532
# Average IV for Puts: 0.7706741552734376
# Total Call Volume: 1088.0
# Total Call open interest: 26343
# Total Call engagement: 27431.0
# Total Put Volume: 1180.0
# Total Put open interest: 8625
# Total Put engagement: 9805.0
# Number of ITM Call Options: 16
# Number of ITM Put Options: 29
# Data fetched for aehr, entries: 173
# ===========================================
# Options data for cmc:
# Average IV for Calls: 0.511823165046938
# Average IV for Puts: 0.566477594884924
# Total Call Volume: 746.0
# Total Call open interest: 25792
# Total Call engagement: 26538.0
# Total Put Volume: 422.0
# Total Put open interest: 5245
# Total Put engagement: 5667.0
# Number of ITM Call Options: 11
# Number of ITM Put Options: 11
# Data fetched for cmc, entries: 180
# ===========================================
# Options data for sgh:
# Average IV for Calls: 0.9494458858235678
# Average IV for Puts: 1.1874787830810551
# Total Call Volume: 689.0
# Total Call open interest: 6087
# Total Call engagement: 6776.0
# Total Put Volume: 195.0
# Total Put open interest: 4085
# Total Put engagement: 4280.0
# Number of ITM Call Options: 5
# Number of ITM Put Options: 8
# Data fetched for sgh, entries: 112
