# %%
from datetime import datetime, timedelta
from analyze_stock import * 

# Set the time frame
end_date = datetime.today()
start_date = end_date - timedelta(days=21)

# Call the function and store the result
tickers =['apld', 'aehr']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # P/e ratio
    plot_pe_ratio(ticker, end_date)

    # IV Skew
    plot_iv_skew_otm_only(options_metrics, end_date, ticker)
# Out:
# ===========================================
# Options data for apld:
# Average IV for Calls: 1.4412503137490913
# Average IV for Puts: 1.4341306596374515
# Total Call Volume: 4995.0
# Total Call open interest: 39048
# Total Call engagement: 44043.0
# Total Put Volume: 2435.0
# Total Put open interest: 29242
# Total Put engagement: 31677.0
# Number of ITM Call Options: 19
# Number of ITM Put Options: 12
# Number of OTM Call Options: 24
# Number of OTM Put Options: 20
# Data fetched for apld, entries: 389
# ===========================================
# Options data for aehr:
# Average IV for Calls: 0.8291289702405427
# Average IV for Puts: 0.7215960050964356
# Total Call Volume: 1455.0
# Total Call open interest: 4435
# Total Call engagement: 5890.0
# Total Put Volume: 1784.0
# Total Put open interest: 8174
# Total Put engagement: 9958.0
# Number of ITM Call Options: 4
# Number of ITM Put Options: 16
# Number of OTM Call Options: 15
# Number of OTM Put Options: 8
# Data fetched for aehr, entries: 387
