# %%
from datetime import datetime, timedelta
from analyze_stock import * 

# Set the time frame
end_date = datetime.today()
start_date = end_date - timedelta(days=21)

# Call the function and store the result
tickers =['aehr', 'sgh']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # P/e ratio
    plot_pe_ratio(ticker, end_date)

    # IV Skew
    plot_iv_skew_for_calls_puts_separately(options_metrics, end_date, ticker)
# Out:
# ===========================================
# Options data for aehr:
# Average IV for Calls: 1.0301212888656126
# Average IV for Puts: 0.8920994139862062
# Total Call Volume: 1873.0
# Total Call open interest: 5265
# Total Call engagement: 7138.0
# Total Put Volume: 1919.0
# Total Put open interest: 7835
# Total Put engagement: 9754.0
# Number of ITM Call Options: 15
# Number of ITM Put Options: 16
# Data fetched for aehr, entries: 349
# ===========================================
# Options data for sgh:
# Average IV for Calls: 0.6943121883138023
# Average IV for Puts: 0.6444127355957031
# Total Call Volume: 239.0
# Total Call open interest: 1724
# Total Call engagement: 1963.0
# Total Put Volume: 138.0
# Total Put open interest: 2989
# Total Put engagement: 3127.0
# Number of ITM Call Options: 8
# Number of ITM Put Options: 7
# Data fetched for sgh, entries: 241
