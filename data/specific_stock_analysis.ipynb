# %%
from datetime import datetime, timedelta
from analyze_stock import * 
from analyze_options import *

# Today
date = datetime.today()

# Set the time frame
end_date = date + timedelta(days=7)
start_date = date - timedelta(days=14)

# Call the function and store the result
tickers =['aehr', 'cmc', 'goss', 'nke', 'sgh']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # Black Scholes
    analyze_and_plot_greeks(ticker)
# Out:
# ===========================================
# Options data for aehr:
# Average IV for Calls: 1.1310070466812607
# Average IV for Puts: 0.7949614338418888
# Total Call Volume: 2251.0
# Total Call open interest: 31352
# Total Call engagement: 33603.0
# Total Put Volume: 1609.0
# Total Put open interest: 10823
# Total Put engagement: 12432.0
# Number of ITM Call Options: 37
# Number of ITM Put Options: 60
# Data fetched for aehr, entries: 252
# ===========================================
# Options data for cmc:
# Average IV for Calls: 0.4703272082461937
# Average IV for Puts: 0.5316896967330933
# Total Call Volume: 455.0
# Total Call open interest: 30433
# Total Call engagement: 30888.0
# Total Put Volume: 470.0
# Total Put open interest: 6903
# Total Put engagement: 7373.0
# Number of ITM Call Options: 37
# Number of ITM Put Options: 26
# Data fetched for cmc, entries: 221
# ===========================================
# Options data for goss:
# Average IV for Calls: 2.207763468523122
# Average IV for Puts: 1.517886144422743
# Total Call Volume: 629.0
# Total Call open interest: 46594
# Total Call engagement: 47223.0
# Total Put Volume: 510.0
# Total Put open interest: 13557
# Total Put engagement: 14067.0
# Number of ITM Call Options: 2
# Number of ITM Put Options: 16
# Data fetched for goss, entries: 162
# ===========================================
# Options data for nke:
# Average IV for Calls: 0.396023132273634
# Average IV for Puts: nan
# Total Call Volume: 40360.0
# Total Call open interest: 379338
# Total Call engagement: 419698.0
# Total Put Volume: 36803.0
# Total Put open interest: 381719.0
# Total Put engagement: 418522.0
# Number of ITM Call Options: 219
# Number of ITM Put Options: 293
# Data fetched for nke, entries: 254
# ===========================================
# Options data for sgh:
# Average IV for Calls: 0.8297402010439919
# Average IV for Puts: 0.9169018196716309
# Total Call Volume: 839.0
# Total Call open interest: 8892
# Total Call engagement: 9731.0
# Total Put Volume: 2547.0
# Total Put open interest: 4602
# Total Put engagement: 7149.0
# Number of ITM Call Options: 17
# Number of ITM Put Options: 21
# Data fetched for sgh, entries: 201
