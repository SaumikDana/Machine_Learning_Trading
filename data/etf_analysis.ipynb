# %%
from datetime import datetime, timedelta
from analyze_stock import * 

# Set the time frame
end_date = datetime.today()
start_date = end_date - timedelta(days=21)

industry_etf_dict = get_sector_etf_for_stock()

tickers = [etf for industry, etf in industry_etf_dict.items() if etf is not None]

for ticker in tickers:

    # Sector ETF Time Series
    plot_stock_historical_data(ticker, start_date, end_date)
