# %%
from datetime import datetime, timedelta
from analyze_stock import * 

# Set the time frame
end_date = datetime.today()
start_date = end_date - timedelta(days=21)

# Call the function and store the result
tickers =['apld', 'aehr', 'goss']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # IV Skew
    plot_iv_skew_otm_only(options_metrics, end_date, ticker)

    # Sector ETF Time Series
    plot_etf_historical_data(ticker, start_date, end_date)
# Out:
# ===========================================
# Options data for apld:
# Average IV for Calls: 1.209648702589466
# Average IV for Puts: 1.0607654703297333
# Total Call Volume: 2046.0
# Total Call open interest: 20227.0
# Total Call engagement: 22273.0
# Total Put Volume: 773.0
# Total Put open interest: 30937
# Total Put engagement: 31710.0
# Number of ITM Call Options: 16
# Number of ITM Put Options: 14
# Number of OTM Call Options: 15
# Number of OTM Put Options: 20
# ===========================================
# ===========================================
# Options data for aehr:
# Average IV for Calls: 0.8557247192891441
# Average IV for Puts: 0.7586795779418946
# Total Call Volume: 2300.0
# Total Call open interest: 10257
# Total Call engagement: 12557.0
# Total Put Volume: 490.0
# Total Put open interest: 8113
# Total Put engagement: 8603.0
# Number of ITM Call Options: 8
# Number of ITM Put Options: 16
# Number of OTM Call Options: 16
# Number of OTM Put Options: 8
# ===========================================
# ===========================================
# Options data for goss:
# Average IV for Calls: 1.3684938899739583
# Average IV for Puts: 1.0494826562500001
# Total Call Volume: 60
# Total Call open interest: 2512
# Total Call engagement: 2572
# Total Put Volume: 56.0
# Total Put open interest: 10479
# Total Put engagement: 10535.0
# Number of ITM Call Options: 0
# Number of ITM Put Options: 6
# Number of OTM Call Options: 6
# Number of OTM Put Options: 0
# ===========================================
