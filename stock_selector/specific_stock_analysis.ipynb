# %%
from datetime import datetime, timedelta
from analyze_stock import * 
from plotting_routines import *

# Set the time frame
end_date = datetime.today()
start_date = end_date - timedelta(days=21)

# Call the function and store the result
tickers =['apld', 'aehr', 'goss']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # IV Skew
    plot_iv_skew_otm_only(options_metrics, end_date, ticker)

    # Sector ETF Time Series
    plot_etf_historical_data(ticker, start_date, end_date)
# Out:
# Information for apld:
# address1: 3811 Turtle Creek Boulevard
# address2: Suite 2100
# city: Dallas
# state: TX
# zip: 75219
# country: United States
# phone: 214 427 1704
# website: https://applieddigital.com
# industry: Capital Markets
# industryKey: capital-markets
# industryDisp: Capital Markets
# sector: Financial Services
# sectorKey: financial-services
# sectorDisp: Financial Services
# longBusinessSummary: Applied Digital Corporation designs, develops, and operates datacenters in North America. Its datacenters provide digital infrastructure solutions to the high-performance computing industry. The company also provides artificial intelligence cloud services, high performance computing datacenter hosting, and crypto datacenter hosting services. The company was formerly known as Applied Blockchain, Inc. and changed its name to Applied Digital Corporation in November 2022. Applied Digital Corporation is based in Dallas, Texas.
# fullTimeEmployees: 121
# companyOfficers: [{'maxAge': 1, 'name': 'Mr. Wesley  Cummins', 'age': 45, 'title': 'Chairman, CEO, President, Secretary & Treasurer', 'yearBorn': 1978, 'fiscalYear': 2023, 'totalPay': 5954578, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. David  Rench', 'age': 45, 'title': 'Chief Financial Officer', 'yearBorn': 1978, 'fiscalYear': 2023, 'totalPay': 2710245, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Michael  Maniscalco', 'age': 43, 'title': 'Chief Technology Officer', 'yearBorn': 1980, 'fiscalYear': 2023, 'totalPay': 1147441, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Jason  Zhang', 'age': 29, 'title': 'Co-Founder', 'yearBorn': 1994, 'fiscalYear': 2023, 'totalPay': 25000, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Nick  Phillips', 'title': 'Executive Vice President of Hosting Operations & Public Affairs', 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. John  Browder', 'title': 'Director of HR and Recruiting', 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Etienne  Snyman', 'title': 'Executive Vice President of Power', 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Roland  Davidson', 'title': 'Executive Vice President of Engineering', 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Brad  Barton', 'title': 'EVP of Real Estate Development', 'fiscalYear': 2023, 'exercisedValue': 0, 'unexercisedValue': 0}]
# auditRisk: 10
# boardRisk: 8
# compensationRisk: 10
# shareHolderRightsRisk: 5
# overallRisk: 10
# governanceEpochDate: 1706745600
# compensationAsOfEpochDate: 1703980800
# maxAge: 86400
# priceHint: 2
# previousClose: 5.02
# open: 5.17
# dayLow: 5.02
# dayHigh: 5.29
# regularMarketPreviousClose: 5.02
# regularMarketOpen: 5.17
# regularMarketDayLow: 5.02
# regularMarketDayHigh: 5.29
# payoutRatio: 0.0
# beta: 4.114
# forwardPE: 12.865854
# volume: 3144751
# regularMarketVolume: 3144751
# averageVolume: 3538508
# averageVolume10days: 2870200
# averageDailyVolume10Day: 2870200
# bid: 4.83
# ask: 4.92
# bidSize: 3200
# askSize: 1100
# marketCap: 643787392
# fiftyTwoWeekLow: 1.74
# fiftyTwoWeekHigh: 11.62
# priceToSalesTrailing12Months: 5.6149964
# fiftyDayAverage: 6.0055
# twoHundredDayAverage: 6.31445
# trailingAnnualDividendRate: 0.0
# trailingAnnualDividendYield: 0.0
# currency: USD
# enterpriseValue: 818112960
# profitMargins: -0.30948
# floatShares: 84011936
# sharesOutstanding: 122045000
# sharesShort: 19994925
# sharesShortPriorMonth: 16798236
# sharesShortPreviousMonthDate: 1703808000
# dateShortInterest: 1706659200
# sharesPercentSharesOut: 0.16379999
# heldPercentInsiders: 0.27631
# heldPercentInstitutions: 0.4984
# shortRatio: 5.04
# shortPercentOfFloat: 0.2065
# impliedSharesOutstanding: 122045000
# bookValue: 1.322
# priceToBook: 3.9901664
# lastFiscalYearEnd: 1685491200
# nextFiscalYearEnd: 1717113600
# mostRecentQuarter: 1701302400
# netIncomeToCommon: -35484000
# trailingEps: -0.37
# forwardEps: 0.41
# lastSplitFactor: 1:6
# lastSplitDate: 1649808000
# enterpriseToRevenue: 7.135
# enterpriseToEbitda: 467.226
# 52WeekChange: 0.7438016
# SandP52WeekChange: 0.21495235
# exchange: NMS
# quoteType: EQUITY
# symbol: APLD
# underlyingSymbol: APLD
# shortName: Applied Digital Corporation
# longName: Applied Digital Corporation
# firstTradeDateEpochUtc: 1649856600
# timeZoneFullName: America/New_York
# timeZoneShortName: EST
# uuid: b6f3f33e-e6a3-3625-aba2-00d4d8143fb7
# messageBoardId: finmb_3563673
# gmtOffSetMilliseconds: -18000000
# currentPrice: 5.275
# targetHighPrice: 19.0
# targetLowPrice: 10.0
# targetMeanPrice: 13.86
# targetMedianPrice: 13.0
# recommendationMean: 2.0
# recommendationKey: buy
# numberOfAnalystOpinions: 7
# totalCash: 9217000
# totalCashPerShare: 0.076
# ebitda: 1751000
# totalDebt: 183544000
# quickRatio: 0.047
# currentRatio: 0.18
# totalRevenue: 114655000
# debtToEquity: 117.915
# revenuePerShare: 1.148
# returnOnAssets: -0.046469998
# returnOnEquity: -0.3214
# freeCashflow: -24646124
# operatingCashflow: 39812000
# revenueGrowth: 2.42
# grossMargins: 0.30235
# ebitdaMargins: 0.015269999
# operatingMargins: -0.18006
# financialCurrency: USD
# trailingPegRatio: None
