# %%
from datetime import datetime, timedelta
from analyze_stock import * 

# Set the time frame
end_date = datetime.today()
start_date = end_date - timedelta(days=21)

# Call the function and store the result
tickers =['apld', 'aehr', 'goss']

for ticker in tickers:
     
    # Use the function from utils.py to analyze stock options
    options_metrics = analyze_stock_options(ticker)

    # Get All Analysis
    get_info(ticker, options_metrics, start_date, end_date)

    # P/e ratio
    plot_pe_ratio(ticker, end_date)

    # IV Skew
    plot_iv_skew_otm_only(options_metrics, end_date, ticker)

    # Sector ETF Time Series
    plot_etf_historical_data(ticker, start_date, end_date)
# Out:
# ===========================================
# Options data for apld:
# Average IV for Calls: 0.11660447798295458
# Average IV for Puts: 0.07433358108108114
# Total Call Volume: 3316.0
# Total Call open interest: 0.0
# Total Call engagement: 3316.0
# Total Put Volume: 1190.0
# Total Put open interest: 0.0
# Total Put engagement: 1190.0
# Number of ITM Call Options: 8
# Number of ITM Put Options: 26
# Number of OTM Call Options: 25
# Number of OTM Put Options: 11
# ===========================================
# ===========================================
# Options data for aehr:
# Average IV for Calls: 0.051103239062500014
# Average IV for Puts: 0.04037417968749996
# Total Call Volume: 563.0
# Total Call open interest: 0.0
# Total Call engagement: 563.0
# Total Put Volume: 523.0
# Total Put open interest: 0.0
# Total Put engagement: 523.0
# Number of ITM Call Options: 8
# Number of ITM Put Options: 16
# Number of OTM Call Options: 17
# Number of OTM Put Options: 8
# ===========================================
# ===========================================
# Options data for goss:
# Average IV for Calls: 0.17188328125
# Average IV for Puts: 0.38802889322916667
# Total Call Volume: 88.0
# Total Call open interest: 0
# Total Call engagement: 88.0
# Total Put Volume: 223.0
# Total Put open interest: 54
# Total Put engagement: 277.0
# Number of ITM Call Options: 0
# Number of ITM Put Options: 6
# Number of OTM Call Options: 6
# Number of OTM Put Options: 0
# ===========================================
# Insufficient variation in strike prices or expiration dates for interpolation.
